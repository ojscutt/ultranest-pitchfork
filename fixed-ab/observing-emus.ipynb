# %% [markdown]
# # observing-emus
# neatened version of notebook `observing-emus.ipynb'

# %%
# stock imports
import tensorflow as tf
import numpy as np
import pandas as pd
import json
import scipy
import os
import random
import pickle

##plotting
import matplotlib.pyplot as plt

# plt.style.use('dark_background')
plt.style.use("Solarize_Light2")
plt.rcParams.update({"axes.edgecolor": "black"})
plt.rcParams.update({"text.color": "black"})
plt.rcParams.update({"axes.labelcolor": "black"})
plt.rcParams.update({"xtick.color": "black"})
plt.rcParams.update({"ytick.color": "black"})
plt.rcParams.update({"font.family": "monospace"})

#script imports
from scripts import prior_funcs, utils

from scripts.pitchfuncs_ultra_pca_v2 import emulator
from scripts.pitchfuncs_ultra_pca_v2 import ultra_ns_vector_surface
from scripts.pitchfuncs_ultra_pca_v2 import ultra_ns_popslice
from scripts.pitchfuncs_ultra_pca_v2 import ultra_ns_popwalk


import logging
logging.getLogger('ultranest').setLevel(logging.WARNING)

os.environ["CUDA_VISIBLE_DEVICES"]="1"

physical_devices = tf.config.list_physical_devices("GPU") 

#os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'


tf.config.experimental.set_memory_growth(physical_devices[0], True)

gpu0usage = tf.config.experimental.get_memory_info("GPU:0")["current"]
# Out:
# 2024-10-10 16:59:37.376191: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-10 16:59:37.386989: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-10 16:59:37.390289: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-10 16:59:37.398734: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-10 16:59:37.958057: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-10-10 16:59:39.377581: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 17539 MB memory:  -> device: 0, name: NVIDIA RTX A4500, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
pitchfork_name = "nu6-40_elu_nonorm_feh"
pitchfork = emulator(pitchfork_name)

with open("pitchfork/" +pitchfork_name+ ".pkl", 'rb') as fp:
     pitchfork_info = pickle.load(fp)

pitchfork_ranges = pitchfork_info['parameter_ranges']
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# initial_mass range: [min = 0.8, max = 1.2]
# initial_Zinit range: [min = 0.003869061466818601, max = 0.0389797119014747]
# initial_Yinit range: [min = 0.24, max = 0.32]
# initial_MLT range: [min = 1.7, max = 2.5]
# star_age range: [min = 0.029664111540787196, max = 13.999973871651315]

# %% [markdown]
# ## emus with freq unc
# applying observational noise to emus, including perturbing the mode frequencies due to the surface term

# %%
for emu_idx in range(25):
    path = f"nest/emu{emu_idx}"
    
    hare_df = pd.read_json(path+f"/emu{emu_idx}.json")

    inps = ["initial_mass", "initial_Zinit", "initial_Yinit", "initial_MLT", "star_age"]
    outs = ['calc_effective_T', 'luminosity', 'star_feh'] + [f'nu_0_{i}' for i in range(6,41)]
    
    hare_inps = hare_df[inps]
    
    emu_outs = pitchfork.predict(hare_inps)

    emu_df = hare_df.copy()

    emu_df[outs] = emu_outs

    emu_df.to_json(path+f"/emu{emu_idx}.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 for emu_idx in range(25):
#       2     path = f"nest/emu{emu_idx}"
# ----> 4     hare_df = pd.read_json(path+f"/emu{emu_idx}.json")
#       6     inps = ["initial_mass", "initial_Zinit", "initial_Yinit", "initial_MLT", "star_age"]
#       7     outs = ['calc_effective_T', 'luminosity', 'star_feh'] + [f'nu_0_{i}' for i in range(6,41)]
#
# File ~/miniconda3/envs/jaxtf/lib/python3.12/site-packages/pandas/io/json/_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
#     798     keep_default_dates=keep_default_dates,
#     799     precise_float=precise_float,
#     800     date_unit=date_unit,
#     801     encoding=encoding,
#     802     lines=lines,
#     803     chunksize=chunksize,
#     804     compression=compression,
#     805     nrows=nrows,
#     806     storage_options=storage_options,
#     807     encoding_errors=encoding_errors,
#     808     dtype_backend=dtype_backend,
#     809     engine=engine,
#     810 )
#     812 if chunksize:
#     813     return json_reader
#
# File ~/miniconda3/envs/jaxtf/lib/python3.12/site-packages/pandas/io/json/_json.py:904, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     902     self.data = filepath_or_buffer
#     903 elif self.engine == "ujson":
# --> 904     data = self._get_data_from_filepath(filepath_or_buffer)
#     905     self.data = self._preprocess_data(data)
#
# File ~/miniconda3/envs/jaxtf/lib/python3.12/site-packages/pandas/io/json/_json.py:960, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     952     filepath_or_buffer = self.handles.handle
#     953 elif (
#     954     isinstance(filepath_or_buffer, str)
#     955     and filepath_or_buffer.lower().endswith(
#    (...)
#     958     and not file_exists(filepath_or_buffer)
#     959 ):
# --> 960     raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     961 else:
#     962     warnings.warn(
#     963         "Passing literal json to 'read_json' is deprecated and "
#     964         "will be removed in a future version. To read from a "
#    (...)
#     967         stacklevel=find_stack_level(),
#     968     )
#
# FileNotFoundError: File nest/emu0/emu0.json does not exist

# %%
def nu_max_range(nu_max_n, mode_min=8, mode_max=16):
    modes = np.random.randint(mode_min, mode_max)
    flip = np.random.randint(2)
    int_half = int(modes * 0.5)
    if flip:
        n_min = nu_max_n - int_half
        n_max = nu_max_n + (modes - int_half)
    else:
        n_min = nu_max_n - (modes - int_half)
        n_max = nu_max_n + int_half

    return n_min, n_max


def obs_noise(true, unc, seed=None):
    seeded_random_state = np.random.RandomState(seed=seed)
    rvs_random_states = seeded_random_state.randint(0, high=2**32 - 1, size=len(true))
    noisy_obs = np.empty(len(true))
    idx = 0
    for ob in true:
        noisy_obs[idx] = scipy.stats.norm(loc=ob, scale=unc[idx]).rvs(
            random_state=rvs_random_states[idx]
        )
        idx += 1

    return noisy_obs


def surf_corr(freqs, nu_max, a, b):
    return freqs + a * ((freqs / nu_max) ** b)


inputs = ["initial_mass", "initial_Zinit", "initial_Yinit", "initial_MLT", "star_age", "a", "b"]

teff_unc = 70  # K
luminosity_unc = 0.04  # L\odot
surface_feh_unc = 0.1  # dex

for obs_idx in range(5):
    for emu_idx in range(100):
        path = f"nest/emu{emu_idx}"
        
        emu_df = pd.read_json(path+f"/emu{emu_idx}.json")
    
        nu_max = emu_df["nu_max"].values[0]
        nu_max_n = emu_df["nu_max_n"].values[0]
        n_min, n_max = nu_max_range(nu_max_n)
        outputs = ["calc_effective_T", "luminosity", "star_feh"] + [
            f"nu_0_{i}" for i in range(n_min, n_max + 1)
        ]
    
        emu_df = emu_df[inputs + outputs]
    
        ### add surface correction
        # generate a and b
        a = emu_df["a"].values[0]
        b = emu_df["b"].values[0]
    
        freqs = emu_df[[f"nu_0_{i}" for i in range(n_min, n_max + 1)]].values[0]
    
        dnu = np.mean(freqs[1:] - freqs[:-1])
    
        #nu_max = freqs.mean()
        # shift frequencies
        freqs_corr = surf_corr(freqs, nu_max, a, b)
    
        # reapply
    
        emu_cut = emu_df.copy()
        emu_cut.loc[:, [f"nu_0_{i}" for i in range(n_min, n_max + 1)]] = freqs_corr
    
        frequency_unc = np.random.uniform(0.1, 1)  # \muHz
    
        obs_unc = np.array(
            [teff_unc, luminosity_unc, surface_feh_unc]
            + [frequency_unc + abs(i - nu_max_n) * 0.1 for i in range(n_min, n_max + 1)]
        )
    
        emu_obs = obs_noise(emu_cut.drop(inputs, axis=1).values[0], obs_unc)
    
        emu_obs = obs_noise(emu_cut[outputs].values[0], obs_unc)
        emu_obs_df = emu_cut.copy()
        emu_obs_df[outputs] = emu_obs
        emu_obs_df[["a", "b"]] = [a, b]
    
        # plt.scatter(emu_obs_df[[f'nu_0_{i}' for i in range(n_min, n_max+1)]]%dnu, emu_obs_df[[f'nu_0_{i}' for i in range(n_min, n_max+1)]], label=f'a={a:.2f}, b={b:.2f}, obs unc')
    
        plt.xlim((0, dnu))
        # plt.legend()
        fig, ax = plt.subplots()
        ax.scatter(
            np.arange(0, len(obs_unc)), (emu_obs - emu_cut[outputs].values[0]) / obs_unc
        )
        ax.axhline(0, c="black")
        ax.axhline(-1, c="black", linestyle="--")
        ax.axhline(1, c="black", linestyle="--")
    
        yabs_max = abs(max(ax.get_ylim(), key=abs))
        ax.set_ylim(ymin=-yabs_max, ymax=yabs_max)
        ax.set_xticks(np.arange(0, len(obs_unc)))
        ax.set_xticklabels(outputs)
        # ax.tick_params(axis='x', labelrotation=90)
    
        plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
        ax.set_title("z-score of observed vs true emu params")
        ax.set_ylabel("z-score")
    
        path += f"/obs{obs_idx}"
        
        if not os.path.exists(path):
            os.mkdir(path)
            print(f"{path} created!")
        else:
            print(f"{path} already exists", end="\r")
        emu_obs_df.to_json(path + f"/obs{obs_idx}.json")
        pd.DataFrame([obs_unc], columns=outputs).to_json(path + "/uncs.json")
        plt.savefig(path + "/zscore_plot.png", bbox_inches="tight")
        plt.close()
plt.close()
# Out:
# nest/emu0/obs0 created!
# nest/emu1/obs0 created!
# nest/emu2/obs0 created!
# nest/emu3/obs0 created!
# nest/emu4/obs0 created!
# nest/emu5/obs0 created!
# nest/emu6/obs0 created!
# nest/emu7/obs0 created!
# nest/emu8/obs0 created!
# nest/emu9/obs0 created!
# nest/emu10/obs0 created!
# nest/emu11/obs0 created!
# nest/emu12/obs0 created!
# nest/emu13/obs0 created!
# nest/emu14/obs0 created!
# nest/emu15/obs0 created!
# nest/emu16/obs0 created!
# nest/emu17/obs0 created!
# nest/emu18/obs0 created!
# nest/emu19/obs0 created!
# nest/emu20/obs0 created!
# nest/emu21/obs0 created!
# nest/emu22/obs0 created!
# nest/emu23/obs0 created!
# nest/emu24/obs0 created!
# nest/emu25/obs0 created!
# nest/emu26/obs0 created!
# nest/emu27/obs0 created!
# nest/emu28/obs0 created!
# nest/emu29/obs0 created!
# nest/emu30/obs0 created!
# nest/emu31/obs0 created!
# nest/emu32/obs0 created!
# nest/emu33/obs0 created!
# nest/emu34/obs0 created!
# nest/emu35/obs0 created!
# nest/emu36/obs0 created!
# nest/emu37/obs0 created!
# nest/emu38/obs0 created!
# nest/emu39/obs0 created!
# nest/emu40/obs0 created!
# nest/emu41/obs0 created!
# nest/emu42/obs0 created!
# nest/emu43/obs0 created!
# nest/emu44/obs0 created!
# nest/emu45/obs0 created!
# nest/emu46/obs0 created!
# nest/emu47/obs0 created!
# nest/emu48/obs0 created!
# nest/emu49/obs0 created!
# nest/emu50/obs0 created!
# nest/emu51/obs0 created!
# nest/emu52/obs0 created!
# nest/emu53/obs0 created!
# nest/emu54/obs0 created!
# nest/emu55/obs0 created!
# nest/emu56/obs0 created!
# nest/emu57/obs0 created!
# nest/emu58/obs0 created!
# nest/emu59/obs0 created!
# nest/emu60/obs0 created!
# nest/emu61/obs0 created!
# nest/emu62/obs0 created!
# nest/emu63/obs0 created!
# nest/emu64/obs0 created!
# nest/emu65/obs0 created!
# nest/emu66/obs0 created!
# nest/emu67/obs0 created!
# nest/emu68/obs0 created!
# nest/emu69/obs0 created!
# nest/emu70/obs0 created!
# nest/emu71/obs0 created!
# nest/emu72/obs0 created!
# nest/emu73/obs0 created!
# nest/emu74/obs0 created!
# nest/emu75/obs0 created!
# nest/emu76/obs0 created!
# nest/emu77/obs0 created!
# nest/emu78/obs0 created!
# nest/emu79/obs0 created!
# nest/emu80/obs0 created!
# nest/emu81/obs0 created!
# nest/emu82/obs0 created!
# nest/emu83/obs0 created!
# nest/emu84/obs0 created!
# nest/emu85/obs0 created!
# nest/emu86/obs0 created!
# nest/emu87/obs0 created!
# nest/emu88/obs0 created!
# nest/emu89/obs0 created!
# nest/emu90/obs0 created!
# nest/emu91/obs0 created!
# nest/emu92/obs0 created!
# nest/emu93/obs0 created!
# nest/emu94/obs0 created!
# nest/emu95/obs0 created!
# nest/emu96/obs0 created!
# nest/emu97/obs0 created!
# nest/emu98/obs0 created!
# nest/emu99/obs0 created!
# nest/emu0/obs1 created!
# nest/emu1/obs1 created!
# nest/emu2/obs1 created!
# nest/emu3/obs1 created!
# nest/emu4/obs1 created!
# nest/emu5/obs1 created!
# nest/emu6/obs1 created!
# nest/emu7/obs1 created!
# nest/emu8/obs1 created!
# nest/emu9/obs1 created!
# nest/emu10/obs1 created!
# nest/emu11/obs1 created!
# nest/emu12/obs1 created!
# nest/emu13/obs1 created!
# nest/emu14/obs1 created!
# nest/emu15/obs1 created!
# nest/emu16/obs1 created!
# nest/emu17/obs1 created!
# nest/emu18/obs1 created!
# nest/emu19/obs1 created!
# nest/emu20/obs1 created!
# nest/emu21/obs1 created!
# nest/emu22/obs1 created!
# nest/emu23/obs1 created!
# nest/emu24/obs1 created!
# nest/emu25/obs1 created!
# nest/emu26/obs1 created!
# nest/emu27/obs1 created!
# nest/emu28/obs1 created!
# nest/emu29/obs1 created!
# nest/emu30/obs1 created!
# nest/emu31/obs1 created!
# nest/emu32/obs1 created!
# nest/emu33/obs1 created!
# nest/emu34/obs1 created!
# nest/emu35/obs1 created!
# nest/emu36/obs1 created!
# nest/emu37/obs1 created!
# nest/emu38/obs1 created!
# nest/emu39/obs1 created!
# nest/emu40/obs1 created!
# nest/emu41/obs1 created!
# nest/emu42/obs1 created!
# nest/emu43/obs1 created!
# nest/emu44/obs1 created!
# nest/emu45/obs1 created!
# nest/emu46/obs1 created!
# nest/emu47/obs1 created!
# nest/emu48/obs1 created!
# nest/emu49/obs1 created!
# nest/emu50/obs1 created!
# nest/emu51/obs1 created!
# nest/emu52/obs1 created!
# nest/emu53/obs1 created!
# nest/emu54/obs1 created!
# nest/emu55/obs1 created!
# nest/emu56/obs1 created!
# nest/emu57/obs1 created!
# nest/emu58/obs1 created!
# nest/emu59/obs1 created!
# nest/emu60/obs1 created!
# nest/emu61/obs1 created!
# nest/emu62/obs1 created!
# nest/emu63/obs1 created!
# nest/emu64/obs1 created!
# nest/emu65/obs1 created!
# nest/emu66/obs1 created!
# nest/emu67/obs1 created!
# nest/emu68/obs1 created!
# nest/emu69/obs1 created!
# nest/emu70/obs1 created!
# nest/emu71/obs1 created!
# nest/emu72/obs1 created!
# nest/emu73/obs1 created!
# nest/emu74/obs1 created!
# nest/emu75/obs1 created!
# nest/emu76/obs1 created!
# nest/emu77/obs1 created!
# nest/emu78/obs1 created!
# nest/emu79/obs1 created!
# nest/emu80/obs1 created!
# nest/emu81/obs1 created!
# nest/emu82/obs1 created!
# nest/emu83/obs1 created!
# nest/emu84/obs1 created!
# nest/emu85/obs1 created!
# nest/emu86/obs1 created!
# nest/emu87/obs1 created!
# nest/emu88/obs1 created!
# nest/emu89/obs1 created!
# nest/emu90/obs1 created!
# nest/emu91/obs1 created!
# nest/emu92/obs1 created!
# nest/emu93/obs1 created!
# nest/emu94/obs1 created!
# nest/emu95/obs1 created!
# nest/emu96/obs1 created!
# nest/emu97/obs1 created!
# nest/emu98/obs1 created!
# nest/emu99/obs1 created!
# nest/emu0/obs2 created!
# nest/emu1/obs2 created!
# nest/emu2/obs2 created!
# nest/emu3/obs2 created!
# nest/emu4/obs2 created!
# nest/emu5/obs2 created!
# nest/emu6/obs2 created!
# nest/emu7/obs2 created!
# nest/emu8/obs2 created!
# nest/emu9/obs2 created!
# nest/emu10/obs2 created!
# nest/emu11/obs2 created!
# nest/emu12/obs2 created!
# nest/emu13/obs2 created!
# nest/emu14/obs2 created!
# nest/emu15/obs2 created!
# nest/emu16/obs2 created!
# nest/emu17/obs2 created!
# nest/emu18/obs2 created!
# nest/emu19/obs2 created!
# nest/emu20/obs2 created!
# nest/emu21/obs2 created!
# nest/emu22/obs2 created!
# nest/emu23/obs2 created!
# nest/emu24/obs2 created!
# nest/emu25/obs2 created!
# nest/emu26/obs2 created!
# nest/emu27/obs2 created!
# nest/emu28/obs2 created!
# nest/emu29/obs2 created!
# nest/emu30/obs2 created!
# nest/emu31/obs2 created!
# nest/emu32/obs2 created!
# nest/emu33/obs2 created!
# nest/emu34/obs2 created!
# nest/emu35/obs2 created!
# nest/emu36/obs2 created!
# nest/emu37/obs2 created!
# nest/emu38/obs2 created!
# nest/emu39/obs2 created!
# nest/emu40/obs2 created!
# nest/emu41/obs2 created!
# nest/emu42/obs2 created!
# nest/emu43/obs2 created!
# nest/emu44/obs2 created!
# nest/emu45/obs2 created!
# nest/emu46/obs2 created!
# nest/emu47/obs2 created!
# nest/emu48/obs2 created!
# nest/emu49/obs2 created!
# nest/emu50/obs2 created!
# nest/emu51/obs2 created!
# nest/emu52/obs2 created!
# nest/emu53/obs2 created!
# nest/emu54/obs2 created!
# nest/emu55/obs2 created!
# nest/emu56/obs2 created!
# nest/emu57/obs2 created!
# nest/emu58/obs2 created!
# nest/emu59/obs2 created!
# nest/emu60/obs2 created!
# nest/emu61/obs2 created!
# nest/emu62/obs2 created!
# nest/emu63/obs2 created!
# nest/emu64/obs2 created!
# nest/emu65/obs2 created!
# nest/emu66/obs2 created!
# nest/emu67/obs2 created!
# nest/emu68/obs2 created!
# nest/emu69/obs2 created!
# nest/emu70/obs2 created!
# nest/emu71/obs2 created!
# nest/emu72/obs2 created!
# nest/emu73/obs2 created!
# nest/emu74/obs2 created!
# nest/emu75/obs2 created!
# nest/emu76/obs2 created!
# nest/emu77/obs2 created!
# nest/emu78/obs2 created!
# nest/emu79/obs2 created!
# nest/emu80/obs2 created!
# nest/emu81/obs2 created!
# nest/emu82/obs2 created!
# nest/emu83/obs2 created!
# nest/emu84/obs2 created!
# nest/emu85/obs2 created!
# nest/emu86/obs2 created!
# nest/emu87/obs2 created!
# nest/emu88/obs2 created!
# nest/emu89/obs2 created!
# nest/emu90/obs2 created!
# nest/emu91/obs2 created!
# nest/emu92/obs2 created!
# nest/emu93/obs2 created!
# nest/emu94/obs2 created!
# nest/emu95/obs2 created!
# nest/emu96/obs2 created!
# nest/emu97/obs2 created!
# nest/emu98/obs2 created!
# nest/emu99/obs2 created!
# nest/emu0/obs3 created!
# nest/emu1/obs3 created!
# nest/emu2/obs3 created!
# nest/emu3/obs3 created!
# nest/emu4/obs3 created!
# nest/emu5/obs3 created!
# nest/emu6/obs3 created!
# nest/emu7/obs3 created!
# nest/emu8/obs3 created!
# nest/emu9/obs3 created!
# nest/emu10/obs3 created!
# nest/emu11/obs3 created!
# nest/emu12/obs3 created!
# nest/emu13/obs3 created!
# nest/emu14/obs3 created!
# nest/emu15/obs3 created!
# nest/emu16/obs3 created!
# nest/emu17/obs3 created!
# nest/emu18/obs3 created!
# nest/emu19/obs3 created!
# nest/emu20/obs3 created!
# nest/emu21/obs3 created!
# nest/emu22/obs3 created!
# nest/emu23/obs3 created!
# nest/emu24/obs3 created!
# nest/emu25/obs3 created!
# nest/emu26/obs3 created!
# nest/emu27/obs3 created!
# nest/emu28/obs3 created!
# nest/emu29/obs3 created!
# nest/emu30/obs3 created!
# nest/emu31/obs3 created!
# nest/emu32/obs3 created!
# nest/emu33/obs3 created!
# nest/emu34/obs3 created!
# nest/emu35/obs3 created!
# nest/emu36/obs3 created!
# nest/emu37/obs3 created!
# nest/emu38/obs3 created!
# nest/emu39/obs3 created!
# nest/emu40/obs3 created!
# nest/emu41/obs3 created!
# nest/emu42/obs3 created!
# nest/emu43/obs3 created!
# nest/emu44/obs3 created!
# nest/emu45/obs3 created!
# nest/emu46/obs3 created!
# nest/emu47/obs3 created!
# nest/emu48/obs3 created!
# nest/emu49/obs3 created!
# nest/emu50/obs3 created!
# nest/emu51/obs3 created!
# nest/emu52/obs3 created!
# nest/emu53/obs3 created!
# nest/emu54/obs3 created!
# nest/emu55/obs3 created!
# nest/emu56/obs3 created!
# nest/emu57/obs3 created!
# nest/emu58/obs3 created!
# nest/emu59/obs3 created!
# nest/emu60/obs3 created!
# nest/emu61/obs3 created!
# nest/emu62/obs3 created!
# nest/emu63/obs3 created!
# nest/emu64/obs3 created!
# nest/emu65/obs3 created!
# nest/emu66/obs3 created!
# nest/emu67/obs3 created!
# nest/emu68/obs3 created!
# nest/emu69/obs3 created!
# nest/emu70/obs3 created!
# nest/emu71/obs3 created!
# nest/emu72/obs3 created!
# nest/emu73/obs3 created!
# nest/emu74/obs3 created!
# nest/emu75/obs3 created!
# nest/emu76/obs3 created!
# nest/emu77/obs3 created!
# nest/emu78/obs3 created!
# nest/emu79/obs3 created!
# nest/emu80/obs3 created!
# nest/emu81/obs3 created!
# nest/emu82/obs3 created!
# nest/emu83/obs3 created!
# nest/emu84/obs3 created!
# nest/emu85/obs3 created!
# nest/emu86/obs3 created!
# nest/emu87/obs3 created!
# nest/emu88/obs3 created!
# nest/emu89/obs3 created!
# nest/emu90/obs3 created!
# nest/emu91/obs3 created!
# nest/emu92/obs3 created!
# nest/emu93/obs3 created!
# nest/emu94/obs3 created!
# nest/emu95/obs3 created!
# nest/emu96/obs3 created!
# nest/emu97/obs3 created!
# nest/emu98/obs3 created!
# nest/emu99/obs3 created!
# nest/emu0/obs4 created!
# nest/emu1/obs4 created!
# nest/emu2/obs4 created!
# nest/emu3/obs4 created!
# nest/emu4/obs4 created!
# nest/emu5/obs4 created!
# nest/emu6/obs4 created!
# nest/emu7/obs4 created!
# nest/emu8/obs4 created!
# nest/emu9/obs4 created!
# nest/emu10/obs4 created!
# nest/emu11/obs4 created!
# nest/emu12/obs4 created!
# nest/emu13/obs4 created!
# nest/emu14/obs4 created!
# nest/emu15/obs4 created!
# nest/emu16/obs4 created!
# nest/emu17/obs4 created!
# nest/emu18/obs4 created!
# nest/emu19/obs4 created!
# nest/emu20/obs4 created!
# nest/emu21/obs4 created!
# nest/emu22/obs4 created!
# nest/emu23/obs4 created!
# nest/emu24/obs4 created!
# nest/emu25/obs4 created!
# nest/emu26/obs4 created!
# nest/emu27/obs4 created!
# nest/emu28/obs4 created!
# nest/emu29/obs4 created!
# nest/emu30/obs4 created!
# nest/emu31/obs4 created!
# nest/emu32/obs4 created!
# nest/emu33/obs4 created!
# nest/emu34/obs4 created!
# nest/emu35/obs4 created!
# nest/emu36/obs4 created!
# nest/emu37/obs4 created!
# nest/emu38/obs4 created!
# nest/emu39/obs4 created!
# nest/emu40/obs4 created!
# nest/emu41/obs4 created!
# nest/emu42/obs4 created!
# nest/emu43/obs4 created!
# nest/emu44/obs4 created!
# nest/emu45/obs4 created!
# nest/emu46/obs4 created!
# nest/emu47/obs4 created!
# nest/emu48/obs4 created!
# nest/emu49/obs4 created!
# nest/emu50/obs4 created!
# nest/emu51/obs4 created!
# nest/emu52/obs4 created!
# nest/emu53/obs4 created!
# nest/emu54/obs4 created!
# nest/emu55/obs4 created!
# nest/emu56/obs4 created!
# nest/emu57/obs4 created!
# nest/emu58/obs4 created!
# nest/emu59/obs4 created!
# nest/emu60/obs4 created!
# nest/emu61/obs4 created!
# nest/emu62/obs4 created!
# nest/emu63/obs4 created!
# nest/emu64/obs4 created!
# nest/emu65/obs4 created!
# nest/emu66/obs4 created!
# nest/emu67/obs4 created!
# nest/emu68/obs4 created!
# nest/emu69/obs4 created!
# nest/emu70/obs4 created!
# nest/emu71/obs4 created!
# nest/emu72/obs4 created!
# nest/emu73/obs4 created!
# nest/emu74/obs4 created!
# nest/emu75/obs4 created!
# nest/emu76/obs4 created!
# nest/emu77/obs4 created!
# nest/emu78/obs4 created!
# nest/emu79/obs4 created!
# nest/emu80/obs4 created!
# nest/emu81/obs4 created!
# nest/emu82/obs4 created!
# nest/emu83/obs4 created!
# nest/emu84/obs4 created!
# nest/emu85/obs4 created!
# nest/emu86/obs4 created!
# nest/emu87/obs4 created!
# nest/emu88/obs4 created!
# nest/emu89/obs4 created!
# nest/emu90/obs4 created!
# nest/emu91/obs4 created!
# nest/emu92/obs4 created!
# nest/emu93/obs4 created!
# nest/emu94/obs4 created!
# nest/emu95/obs4 created!
# nest/emu96/obs4 created!
# nest/emu97/obs4 created!
# nest/emu98/obs4 created!
# nest/emu99/obs4 created!
